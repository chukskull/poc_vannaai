# %% [markdown]
# <a href="https://colab.research.google.com/github/chukskull/poc_vannaai/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vanna
import vanna
from vanna.remote import VannaDefault
from google.colab import output
output.serve_kernel_port_as_iframe(8084)
vn = VannaDefault(model='chinook', api_key=vanna.get_api_key('natalia.nagat1@gmail.com'))
vn.connect_to_sqlite('https://vanna.ai/Chinook.sqlite')
vn.ask("What are the top 10 albums by sales?")
# Out:
# ...
# Check your email for the code and enter it here: 56LVPJ
# ...

# %%
from vanna.flask import VannaFlaskApp
VannaFlaskApp(vn).run()
# Out:
# Google Colab doesn't support running websocket servers. Disabling debug mode.
# ...
# Try `serve_kernel_port_as_iframe` instead.
# Your app is running at:
# https://efli55b82pv-496ff2e9c6d22116-8084-colab.googleusercontent.com/
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: off

# %% [markdown]
# ## Here's what you'll get
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)
